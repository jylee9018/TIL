# %% [markdown]
# ## Morphological Transform
# [출처] https://docs.opencv.org/4.10.0/d9/d61/tutorial_py_morphological_ops.html

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

img = cv.imread("j.png", cv.IMREAD_GRAYSCALE)
assert img is not None, "file could not be read, check with os.path.exists()"
kernel = np.ones((5, 5), np.uint8)
img_erosion = cv.erode(img, kernel, iterations=1)
img_dilation = cv.dilate(img, kernel, iterations=1)

# %%
print(img.shape)
# Out:
# (150, 112)

# %%
plt.figure(figsize=(15, 10))
plt.subplot(1, 4, 1)
plt.imshow(img, cmap="gray")

plt.subplot(1, 4, 2)
plt.imshow(img_erosion, cmap="gray")

plt.subplot(1, 4, 3)
plt.imshow(img_dilation, cmap="gray")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 12
#       9 plt.imshow(img_dilation, cmap="gray")
#      11 plt.subplot(1, 4, 4)
# ---> 12 plt.imshow(img_opening, cmap="gray")
#      14 plt.show()
#
# NameError: name 'img_opening' is not defined

# %%
np.set_printoptions(linewidth=np.inf)
print(img[:15, 65:85])
print("\n")
print(img_erosion[:15, 65:85])

# %% [markdown]
# ### 필터 동작 원리

# %% [markdown]
# ![image.png](attachment:image.png)
